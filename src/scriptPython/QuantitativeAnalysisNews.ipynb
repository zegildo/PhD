# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame, Panel
pd.set_option('max_rows', 15) # this limit maximum numbers of rows

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ao = pd.read_csv('/home/zegildo/Downloads/IndiceIbovespa.csv', index_col='data', parse_dates=True, dayfirst=True)

# %%
ao.head()
# Out:
#                preco           variacao  quantidade
# data
# 2015-06-15  53137.53  -1,02625310331764      813123
# 2015-06-12  53347.53              -0,64     2453109
# 2015-06-11  53688.51              -0,35     3189181
# 2015-06-10  53876.44               2,01     3698521
# 2015-06-09  52815.99               0,01     3791772

# %%
datas = ao.index.values

# %%
print(datas)
# Out:
# ['2015-06-14T21:00:00.000000000-0300' '2015-06-11T21:00:00.000000000-0300'
#  '2015-06-10T21:00:00.000000000-0300' ...,
#  '2005-06-19T21:00:00.000000000-0300' '2005-06-16T21:00:00.000000000-0300'
#  '2005-06-15T21:00:00.000000000-0300']

# %%
precos = ao['preco'].values

# %%
print(precos)
# Out:
# [ 53137.53  53347.53  53688.51 ...,  26045.5   26092.88  25750.53]

# %%
AO = Series(precos,index=datas)

# %%
AO.plot()

# %%
AO['12/06/2015':'30/12/2009'].plot()

# %%
AO['2012'].plot()

# %%
AO['2012-06'].plot()

# %%
AO[1]
# Out:
# 53347.529999999999

# %%
AO['2012-01']
# Out:
# 2012-01-31    63072.31
# 2012-01-30    62770.01
# 2012-01-27    62904.20
# 2012-01-26    62953.06
# 2012-01-24    62486.22
# ...
# 2012-01-09    59082.88
# 2012-01-06    58600.37
# 2012-01-05    58546.08
# 2012-01-04    59364.95
# 2012-01-03    59264.87
# 2012-01-02    57829.27
# Length: 21

# %%
AO['2015-05':'2012-01']
# Out:
# 2015-04-30    56229.38
# 2015-04-29    55325.29
# 2015-04-28    55812.03
# 2015-04-27    55534.50
# 2015-04-24    56594.22
# ...
# 2012-02-08    65831.16
# 2012-02-07    65917.02
# 2012-02-06    65223.72
# 2012-02-03    65217.37
# 2012-02-02    64593.10
# 2012-02-01    64567.18
# Length: 804

# %%
AO[AO < 50000]
# Out:
# 2015-03-16    48848.21
# 2015-03-13    48595.81
# 2015-03-12    48880.40
# 2015-03-11    48905.58
# 2015-03-10    48293.40
# ...
# 2005-06-23    24815.58
# 2005-06-22    25678.25
# 2005-06-21    25721.68
# 2005-06-20    26045.50
# 2005-06-17    26092.88
# 2005-06-16    25750.53
# Length: 780

# %%
estadao = pd.read_csv('/home/zegildo/serieNoticiasESTADAO.txt', index_col='data', parse_dates=True)

# %%
estadao.head()
# Out:
#             quantidade
# data
# 2014-04-28          60
# 2015-02-28          21
# 2015-02-27          23
# 2015-02-26          30
# 2015-02-25          20

# %%
datasEstadao = estadao.index.values

# %%
datasEstadao
# Out:
# array(['2014-04-27T21:00:00.000000000-0300',
#        '2015-02-27T21:00:00.000000000-0300',
#        '2015-02-26T21:00:00.000000000-0300', ...,
#        '2002-12-21T21:00:00.000000000-0300',
#        '2002-12-14T21:00:00.000000000-0300',
#        '2003-04-04T21:00:00.000000000-0300'], dtype='datetime64[ns]')

# %%
numeroNoticias = estadao['quantidade'].values

# %%
numeroNoticias
# Out:
# array([60, 21, 23, ...,  8,  6,  2])

# %%
volumeNoticiasDiarioESTADAO = Series(numeroNoticias,index=datasEstadao)

# %%
volumeNoticiasDiarioESTADAO.plot()

# %%
volumeNoticiasDiarioESTADAO['2012-07':'2012-08'].plot()

# %%
volumeNoticiasDiarioESTADAO['2006'].plot()

# %%
AO['2012-10':'2012-05'].plot()

# %%
volumeNoticiasDiarioESTADAO['2012-06':'2012-09'].plot()
